# %% [markdown]
# A contour plot is a graphical method to visualize the 3-D surface by plotting constant Z slices called contours in a 2-D format. The contour plot is an alternative to a 3-D surface plot
#
# The contour plot is formed by:
#
# 1.Vertical axis: Independent variable 2
#
# 2.Horizontal axis: Independent variable 1
#
# 3.Lines: iso-response values, can be calculated with the help (x,y).

# %% [raw]
# Three Matplotlib functions are used for this purpose. They are :
#
# a) plt.contour for contour plots,
#
# b) plt.contourf for filled contour plots,
#
# c) plt.imshow for showing images.

# %%
# Import Iris dataset

# !pip install matplotlib pandas numpy seaborn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

from sklearn.datasets import load_iris

#load the dataset
iris = load_iris()

# Convert to pandas DataFrame
iris_df = pd.DataFrame(data=iris.data,columns=iris.feature_names)

# Add the target column
iris_df['target'] = iris.target

# %%
iris_target_0 = iris_df[iris_df['target'] == 0]

sns.jointplot(x='petal length (cm)', y='petal width (cm)', data = iris_target_0, kind='kde',fill=True)
plt.show()

# %% [raw]
# Above we have plotted the graph considering only target 0 with petal length and pental width features
# The darker area respresent area with high density of data points......
